# %%
# !pip install numpy pandas matplotlib torch torchmetrics
# Out:
# Requirement already satisfied: numpy in /Users/chris/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: pandas in /Users/chris/anaconda3/lib/python3.11/site-packages (2.2.3)
# Requirement already satisfied: matplotlib in /Users/chris/anaconda3/lib/python3.11/site-packages (3.7.2)
# Requirement already satisfied: torch in /Users/chris/anaconda3/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: torchmetrics in /Users/chris/anaconda3/lib/python3.11/site-packages (1.6.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas) (2023.3)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.0.5)
# Requirement already satisfied: cycler>=0.10 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (4.25.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: packaging>=20.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (23.1)
# Requirement already satisfied: pillow>=6.2.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (10.0.1)
# Requirement already satisfied: pyparsing<3.1,>=2.3.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: filelock in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (4.12.2)
# Requirement already satisfied: sympy in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (1.14.0)
# Requirement already satisfied: networkx in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (3.1)
# Requirement already satisfied: jinja2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (3.1.2)
# Requirement already satisfied: fsspec in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch) (2023.4.0)
# Requirement already satisfied: lightning-utilities>=0.8.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torchmetrics) (0.12.0)
# Requirement already satisfied: setuptools in /Users/chris/anaconda3/lib/python3.11/site-packages (from lightning-utilities>=0.8.0->torchmetrics) (68.0.0)
# Requirement already satisfied: six>=1.5 in /Users/chris/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from jinja2->torch) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from sympy->torch) (1.3.0)

# %%
# Minimal PyTorch CUDA availability check - fail fast if CUDA is unavailable
try:
    import torch
except Exception as e:
    raise RuntimeError(f"PyTorch is not installed or failed to import: {e}")

# Ensure CUDA is available - if not, raise an error because we rely on GPU
if not torch.cuda.is_available():
    raise RuntimeError("CUDA is not available. Please ensure an NVIDIA GPU, drivers, and CUDA are installed and that the CUDA toolkit is compatible with your PyTorch build.")

# Report devices
print('PyTorch version:', torch.__version__)
cnt = torch.cuda.device_count()
print('CUDA device count:', cnt)
for i in range(cnt):
    try:
        name = torch.cuda.get_device_name(i)
    except Exception:
        name = f'unknown-device-{i}'
    print(f'Device {i}:', name)

# Quick allocation test to confirm functional GPU access
try:
    _ = torch.zeros(1, device='cuda')
    print('Successfully allocated a tensor on CUDA.')
except Exception as e:
    raise RuntimeError('CUDA appears available but tensor allocation failed: ' + str(e))
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[2], line 9
#       7 # Ensure CUDA is available - if not, raise an error because we rely on GPU
#       8 if not torch.cuda.is_available():
# ----> 9     raise RuntimeError("CUDA is not available. Please ensure an NVIDIA GPU, drivers, and CUDA are installed and that the CUDA toolkit is compatible with your PyTorch build.")
#      11 # Report devices
#      12 print('PyTorch version:', torch.__version__)
#
# RuntimeError: CUDA is not available. Please ensure an NVIDIA GPU, drivers, and CUDA are installed and that the CUDA toolkit is compatible with your PyTorch build.

# %%
#alternate dependencies for running on mac withough CUDA

# !pip install pydantic
# !pip install PyYAML
# !pip install numpy==1.26.4
# !pip install torch==2.1.1 torchdata==0.7.1
# !pip install dgl -f https://data.dgl.ai/wheels/repo.html

# use pip install  dgl -f https://data.dgl.ai/wheels/torch-2.1/cu121/repo.html to install dgl for linux with CUDA
# Out:
# Requirement already satisfied: pydantic in /Users/chris/anaconda3/lib/python3.11/site-packages (1.10.8)
# Requirement already satisfied: typing-extensions>=4.2.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pydantic) (4.12.2)
# Requirement already satisfied: PyYAML in /Users/chris/anaconda3/lib/python3.11/site-packages (6.0)
# Requirement already satisfied: numpy==1.26.4 in /Users/chris/anaconda3/lib/python3.11/site-packages (1.26.4)
# Requirement already satisfied: torch==2.1.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (2.1.1)
# Requirement already satisfied: torchdata==0.7.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (0.7.1)
# Requirement already satisfied: filelock in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (4.12.2)
# Requirement already satisfied: sympy in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (1.14.0)
# Requirement already satisfied: networkx in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (3.1)
# Requirement already satisfied: jinja2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (3.1.2)
# Requirement already satisfied: fsspec in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch==2.1.1) (2023.4.0)
# Requirement already satisfied: urllib3>=1.25 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torchdata==0.7.1) (1.26.16)
# Requirement already satisfied: requests in /Users/chris/anaconda3/lib/python3.11/site-packages (from torchdata==0.7.1) (2.31.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from jinja2->torch==2.1.1) (2.1.1)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests->torchdata==0.7.1) (2023.11.17)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from sympy->torch==2.1.1) (1.3.0)
# Looking in links: https://data.dgl.ai/wheels/repo.html
# Requirement already satisfied: dgl in /Users/chris/anaconda3/lib/python3.11/site-packages (2.2.1)
# Requirement already satisfied: numpy>=1.14.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (1.26.4)
# Requirement already satisfied: scipy>=1.1.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (1.11.1)
# Requirement already satisfied: networkx>=2.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (3.1)
# Requirement already satisfied: requests>=2.19.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (2.31.0)
# Requirement already satisfied: tqdm in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (4.65.0)
# Requirement already satisfied: psutil>=5.8.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (5.9.0)
# Requirement already satisfied: torchdata>=0.5.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (0.7.1)
# Requirement already satisfied: pandas in /Users/chris/anaconda3/lib/python3.11/site-packages (from dgl) (2.2.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->dgl) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->dgl) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->dgl) (1.26.16)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/chris/anaconda3/lib/python3.11/site-packages (from requests>=2.19.0->dgl) (2023.11.17)
# Requirement already satisfied: torch>=2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torchdata>=0.5.0->dgl) (2.1.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas->dgl) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas->dgl) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /Users/chris/anaconda3/lib/python3.11/site-packages (from pandas->dgl) (2023.3)
# Requirement already satisfied: six>=1.5 in /Users/chris/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas->dgl) (1.16.0)
# Requirement already satisfied: filelock in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.9.0)
# Requirement already satisfied: typing-extensions in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (4.12.2)
# Requirement already satisfied: sympy in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (3.1.2)
# Requirement already satisfied: fsspec in /Users/chris/anaconda3/lib/python3.11/site-packages (from torch>=2->torchdata>=0.5.0->dgl) (2023.4.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=2->torchdata>=0.5.0->dgl) (2.1.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/chris/anaconda3/lib/python3.11/site-packages (from sympy->torch>=2->torchdata>=0.5.0->dgl) (1.3.0)

# %%
import pandas as pd
from pathlib import Path

# Path to the small transactions CSV (relative to this notebook).
DATA_PATH = Path("dataset") / "HI-Small_Trans.csv"

# Load into a DataFrame
small_trans = pd.read_csv(DATA_PATH)

# Quick summary and preview
print(f"Loaded {len(small_trans)} rows; columns: {list(small_trans.columns)}")
small_trans.head()
# Out:
# Loaded 5078345 rows; columns: ['Timestamp', 'From Bank', 'Account', 'To Bank', 'Account.1', 'Amount Received', 'Receiving Currency', 'Amount Paid', 'Payment Currency', 'Payment Format', 'Is Laundering']
#           Timestamp  From Bank    Account  To Bank  Account.1  \
# 0  2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1  2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2  2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3  2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4  2022/09/01 00:06         10  8000F5200       10  8000F5200
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34          US Dollar      3697.34        US Dollar
# 1             0.01          US Dollar         0.01        US Dollar
# 2         14675.57          US Dollar     14675.57        US Dollar
# 3          2806.97          US Dollar      2806.97        US Dollar
# 4         36682.97          US Dollar     36682.97        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0

# %%
# Basic analysis: currencies, banks, and other summaries
# This cell is robust to different column names: it searches for currency-like and bank-like columns

# Show shape and a small sample
rows, cols = small_trans.shape
print(f"Data shape: {rows} rows x {cols} columns")
print()
print("Sample rows:")
display(small_trans.head())

# Missing values by column (top 10)
missing_by_col = small_trans.isnull().sum().sort_values(ascending=False).head(15)
print("Top missing values by column:")
print(missing_by_col.to_string())
print()

# Find likely currency column(s)
currency_candidates = [c for c in small_trans.columns if any(k in c.lower() for k in ('currency','ccy','curr'))]
if currency_candidates:
    cur_col = currency_candidates[0]
    num_currencies = small_trans[cur_col].nunique(dropna=True)
    top_currencies = small_trans[cur_col].value_counts().head(10)
    print(f"Found currency column: '{cur_col}' — {num_currencies} unique values")
    print("Top currencies (by count):")
    print(top_currencies.to_string())
else:
    cur_col = None
    print("No currency-like column found.")
    print("Columns:", list(small_trans.columns))

print()
# Find likely bank-related columns
bank_candidates = [c for c in small_trans.columns if any(k in c.lower() for k in ('bank','institution','bic','iban','bankid','bank_id','bankname','bank_name'))]
if bank_candidates:
    # Count unique bank identifiers across candidate columns
    unique_banks = set()
    for c in bank_candidates:
        unique_banks.update(small_trans[c].dropna().astype(str).unique())
    num_unique_banks = len(unique_banks)
    print(f"Found bank-like columns: {bank_candidates} — approx. {num_unique_banks} unique bank identifiers (aggregated)")
else:
    num_unique_banks = None
    print("No bank-like columns found.")

print()
# Other basic summaries: amount column candidates and top senders/receivers if available
amt_candidates = [c for c in small_trans.columns if any(k in c.lower() for k in ('amount','amt','value'))]
if amt_candidates:
    amt_col = amt_candidates[0]
    print(f"Found amount column: {amt_col} — summary:")
    print(small_trans[amt_col].describe())
else:
    print("No amount-like column found.")

# If sender/receiver columns exist, show top participants
party_candidates = [c for c in small_trans.columns if any(k in c.lower() for k in ('sender','receiver','originator','beneficiary','from_','to_','account'))]
if party_candidates:
    print()
    print("Top participants in party-like columns:")
    for c in party_candidates:
        print(f"Column: {c}")
# Final small sample
display(small_trans.sample(min(5, len(small_trans))))
# Out:
# Data shape: 5078345 rows x 11 columns
#
# Sample rows:
#           Timestamp  From Bank    Account  To Bank  Account.1  \
# 0  2022/09/01 00:20         10  8000EBD30       10  8000EBD30
# 1  2022/09/01 00:20       3208  8000F4580        1  8000F5340
# 2  2022/09/01 00:00       3209  8000F4670     3209  8000F4670
# 3  2022/09/01 00:02         12  8000F5030       12  8000F5030
# 4  2022/09/01 00:06         10  8000F5200       10  8000F5200
#
#    Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 0          3697.34          US Dollar      3697.34        US Dollar
# 1             0.01          US Dollar         0.01        US Dollar
# 2         14675.57          US Dollar     14675.57        US Dollar
# 3          2806.97          US Dollar      2806.97        US Dollar
# 4         36682.97          US Dollar     36682.97        US Dollar
#
#   Payment Format  Is Laundering
# 0   Reinvestment              0
# 1         Cheque              0
# 2   Reinvestment              0
# 3   Reinvestment              0
# 4   Reinvestment              0
# Top missing values by column:
# Timestamp             0
# From Bank             0
# Account               0
# To Bank               0
# Account.1             0
# Amount Received       0
# Receiving Currency    0
# Amount Paid           0
# Payment Currency      0
# Payment Format        0
# Is Laundering         0
#
# Found currency column: 'Receiving Currency' — 15 unique values
# Top currencies (by count):
# Receiving Currency
# US Dollar      1879341
# Euro           1172017
# Swiss Franc     237884
# Yuan            206551
# Shekel          194988
# Rupee           192065
# UK Pound        181255
# Ruble           157361
# Yen             156319
# Bitcoin         148151
#
# Found bank-like columns: ['From Bank', 'To Bank'] — approx. 30470 unique bank identifiers (aggregated)
#
# Found amount column: Amount Received — summary:
# count    5.078345e+06
# mean     5.988726e+06
# std      1.037183e+09
# min      1.000000e-06
# 25%      1.833700e+02
# 50%      1.411010e+03
# 75%      1.234627e+04
# max      1.046302e+12
# Name: Amount Received, dtype: float64
#
# Top participants in party-like columns:
# Column: Account
# Column: Account.1
#                 Timestamp  From Bank    Account  To Bank  Account.1  \
# 527261   2022/09/01 06:03     143430  810945FD0   143430  810945FD0
# 1842936  2022/09/02 23:14       3698  80188A4D0     2385  80B8CF2C0
# 334014   2022/09/01 00:49      11056  8006C08F0    11852  8014E6C60
# 1695811  2022/09/02 18:19         21  803B1D230    10656  8040CCFD0
# 4803577  2022/09/09 21:48         70  100428660       10  800454440
#
#          Amount Received Receiving Currency  Amount Paid Payment Currency  \
# 527261          26126.51             Shekel     26126.51           Shekel
# 1842936           588.84          US Dollar       588.84        US Dollar
# 334014          49926.27               Euro     49926.27             Euro
# 1695811         57836.53                Yen     57836.53              Yen
# 4803577           168.74          US Dollar       168.74        US Dollar
#
#         Payment Format  Is Laundering
# 527261    Reinvestment              0
# 1842936            ACH              0
# 334014            Wire              0
# 1695811           Wire              0
# 4803577           Cash              0

# %%
import pandas as pd
import numpy as np
import torch
import dgl

from datetime import datetime
from sklearn.preprocessing import OneHotEncoder

# %%
# account numbers are in hexadecimal and need to be converted to int
hex_to_int = np.vectorize(lambda x: int(x, 16))

# create adjacency lists to represent the graph
source = hex_to_int(small_trans['Account'])
target = hex_to_int(small_trans['Account.1'])

# %%
# create directed graph using dgl
g_accounts = dgl.graph((source, target))
g = dgl.compact_graphs(g_accounts)

# can recover account number ints by g.ndata[dgl.NID]

# %%
# need to convert times from utc strings to unix floats
utc_to_unix = np.vectorize(lambda x: datetime.strptime(x, "%Y/%m/%d %H:%M").timestamp())

# extract individual edge features
time = utc_to_unix(small_trans['Timestamp'])
amount_paid = small_trans['Amount Paid'].to_numpy()
amount_received = small_trans['Amount Received'].to_numpy()

# use one-hot encoding for categorical variables
encoder = OneHotEncoder(sparse_output=False)

paid_currency = encoder.fit_transform(small_trans['Payment Currency'].to_numpy().reshape(-1, 1))
received_currency = encoder.fit_transform(small_trans['Receiving Currency'].to_numpy().reshape(-1, 1))
pay_format = encoder.fit_transform(small_trans['Payment Format'].to_numpy().reshape(-1, 1))

# combine edge features into single tensor
edge_features = torch.cat((torch.transpose(torch.tensor([time, amount_paid, amount_received]), 0, 1), 
                           torch.tensor(paid_currency), torch.tensor(received_currency), torch.tensor(pay_format)), 1)

# create y edge labels
fraud_label = torch.tensor(small_trans['Is Laundering'])

# attach features and labels to graph
g.edata['features'] = edge_features
g.edata['label'] = fraud_label

# %%
print(g)
# Out:
# Graph(num_nodes=515080, num_edges=5078345,
#       ndata_schemes={'_ID': Scheme(shape=(), dtype=torch.int64)}
#       edata_schemes={'features': Scheme(shape=(40,), dtype=torch.float64), 'label': Scheme(shape=(), dtype=torch.int64)})

# %%
# use unshuffled 60/20/20 train/val/test split based on documentation
train_nodes, val_nodes, test_nodes = dgl.data.utils.split_dataset(g.nodes(), frac_list=[0.6, 0.2, 0.2])
train = dgl.node_subgraph(g, train_nodes)
val = dgl.node_subgraph(g, val_nodes)
test = dgl.node_subgraph(g, test_nodes)
